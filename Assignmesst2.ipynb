# %% [markdown]
# # 1. Task: Calculate Profit , loss Percentage

# %%
CP=int(input("enter CP:"))
SP=int(input("enter SP:"))
if SP>CP:
    profit=SP-CP
    per_profit=(profit/CP)*100
    print("per_profit=",per_profit)
elif CP>SP:
    loss=CP-SP
    per_loss=(loss/CP)*100
    print("per_loss=",per_loss)
else:
    print("not profit and not loss")
# Out:
# enter CP: 300
# enter SP: 500
# per_profit= 66.66666666666666

# %% [markdown]
# # 2. Task: Cricket Stats Analyzer

# %%
player1=int(input("enter player1 score:"))
player2=int(input("enter player2 score:"))
player3=int(input("enter player3 score:"))
player4=int(input("enter player4 score:"))
player5=int(input("enter player5 score:"))
total_runs= player1+player2+player3+player4+player5
avg_runs=total_runs/5
print("total runs=",total_runs)
print("avg runs=",avg_runs)
# Out:
# enter player1 score: 23
# enter player2 score: 45
# enter player3 score: 67
# enter player4 score: 89
# enter player5 score: 90
# total runs= 314
# avg runs= 62.8

# %% [markdown]
# # 3. Task: Retirement Age Calculator

# %%
age=int(input("enter your age:"))
remaining_age=65-age
if age<65:
    print(f"after {remaining_age} year you are retired")
else:
    print("you are retired")
# Out:
# enter your age: 55
# after 10 year you are retired

# %% [markdown]
# # 4. Task: Calculate the Area of a Circle

# %%
radius=float(input("enter radius of circle"))
area=3.141*(radius)**2
print("area of the circle is:",area)
# Out:
# enter radius of circle 5
# area of the circle is: 78.525

# %% [markdown]
# # 5. Task: Salary Calculation

# %%
salary=float(input("enter your base salary"))
bonus=float(input("enter your bonus"))
tax_rate=float(input("enter your tax rate"))
other_charges=float(input("enter your other charges"))
Gross_Salary=salary+bonus
tax=(Gross_Salary*tax_rate)/100
net_salary=Gross_Salary-(tax+other_charges)
print("your gross salary is:",Gross_Salary)
print("your tax is:",tax)
print("your net salary is:",net_salary)
# Out:
# enter your base salary 5000
# enter your bonus 500
# enter your tax rate 10
# enter your other charges 200
# your gross salary is: 5500.0
# your tax is: 550.0
# your net salary is: 4750.0

# %% [markdown]
# # 6. Task: Bank Loan Approval System

# %%
age=int(input("enter your age"))
if age>18 and age<60:
    income=float(input("enter your monthly income:"))
    if income>=25000.0:
        score=int(input("enter your credit score:"))
        if score>=700:
            debts=float(input("enter you outstanding debts:"))
            if debts>10000.0:
                print("Loan Approve")
            else:
                print("Loan Rejected")
        else:
            print("Loan Rejected")
    else:
        print("Loan Rejected")
else:
    print("Loan Rejected")
# Out:
# enter your age 23
# enter your monthly income: 25600
# enter your credit score: 750
# enter you outstanding debts: 12000
# Loan Approve

# %% [markdown]
# # 7. Task: Students Interview Eligibility Checker

# %%
score=float(input("enter student scorein percentage:"))
if score>=60:
    attendance=float(input("enter student attendance inn percentage:"))
    if attendance>=75:
        extra_car=int(input("enter no of Extracurricular Participation:"))
        if extra_car>=1:
            print("Eligible for Interview")
        else:
            print("Not Eligible for Interview")
    else:
        print("Not Eligible for Interview")
else:
    print("Not Eligible for Interview")
# Out:
# enter student scorein percentage: 70
# enter student attendance inn percentage: 88.5
# enter no of Extracurricular Participation: 4
# Eligible for Interview

# %% [markdown]
# # 8. Task: Validating Email Domain

# %%
email=input("enter your gmail")
if "@gmail.com" not in email:
    print("invlaid gmail")
else:
    print("vlaid gamil")
# Out:
# enter your gmail akshpal@gmail.com
# vlaid gamil

# %% [markdown]
# # 9.Task : Student Grading System

# %%
marks=int(input("enter the marks of student:"))
if marks>=0 and marks<=100:
    if marks>=0 and marks<=49:
        print("Gread:F")
    elif marks>=50 and marks<=59:
        print("Gread:E")
    elif marks>=60 and marks<=69:
        print("Gread:D")
    elif marks>=70 and marks<=79:
        print("Gread:C")
    elif marks>=80 and marks<=89:
        print("Gread:B")
    else:
        print("Gread:A")
else:
    print("invlaid marks")
# Out:
# enter the marks of student: 90
# Gread:A

# %% [markdown]
# # 10.Task : Authentication System.

# %%
username=input("enter use name:")
password=input("enter password:")
username1 = "user1" 
username1_password1 = "pass@123"
if username==username1 and password==username1_password1:
    print("Authentication successful")
else:
    print("Authentication failed.")
# Out:
# enter use name: shdgfbfjk
# enter password: hfsfjkfnw
# Authentication failed.

# %% [markdown]
# # 12.Employee Salary Based on Experience.

# %%
exp=int(input("enter year of experiance:"))
if exp<=5:
    print(f"Junior Employee with {exp} years of experience:")
    print("salary:30000")
elif exp>5 and exp<=9:
    print(f"Mid-level Employee with {exp} years of experience:")
    print("salary:50000")
else:
    print(f"senior Employee with {exp} years of experience:")
    if exp>=15:
        print("salary:85000")
    else:
        print("salary:80000")
# Out:
# enter year of experiance: 18
# senior Employee with 18 years of experience:
# salary:85000

# %% [markdown]
# # 13. Library Charge Calculation

# %%
borrow=int(input("enter the number of days the book has been borrowed."))
if borrow>=1 and borrow<=5:
    print("charge is :",borrow*2)
elif borrow>=6 and borrow<=10:
    print("charge is :",borrow*3)
elif borrow>=11 and borrow<=15:
    print("charge is :",borrow*4)
else:
    print("charge is :",borrow*5)
# Out:
# enter the number of days the book has been borrowed. 27
# charge is : 135

# %% [markdown]
# # 14. Arranging Three Numbers in Descending Order

# %%
num1=int(input("enter the 1st num:"))
num2=int(input("enter the 2nd num:"))
num3=int(input("enter the 3rd num:"))
if num1>=num2 and num1>=num3:
    if num2>=num3:
        print("Numbers in Descending Orde:",num1,num2,num3)
    else:
        print("Numbers in Descending Orde:",num1,num3,num2)
elif num2>=num1 and num2>=num3:
    if num1>=num3:
        print("Numbers in Descending Orde:",num2,num1,num3)
    else:
        print("Numbers in Descending Orde:",num2,num1,num3)
else:
    if num1>=num2:
        print("Numbers in Descending Order:",num3,num1,num2)
    else:
        print("Numbers in Descending Order:",num3,num2,num1)
# Out:
# enter the 1st num: 9
# enter the 2nd num: 8
# enter the 3rd num: 8
# Numbers in Descending Orde: 9 8 8

# %% [markdown]
# # 15. Tax Calculation for Car Purchase

# %%
car=input("enter the car brand name:")
price=int(input("enter the car price:"))
if car=="mahindra":
    if price>=700000 and price<=1000000:
        tax=(price*5)/100
        print("tax is:",tax)
    else:
        print("no tax apply")
elif car=="audi":
    if price>=1000000 and price<=1500000:
        tax=(price*10)/100
        print("tax is:",tax)
    else:
        print("no tax apply")
elif car=="jaguar":
    if price>=1500000 and price<=2000000:
        tax=(price*25)/100
        print("tax is:",tax)
    else:
        print("no tax apply")
elif car=="mercedes":
    if price>=2000000 and price<=2500000:
        tax=(price*30)/100
        print("tax is:",tax)
    else:
        print("no tax apply")
# Out:
# enter the car brand name: audi
# enter the car price: 1200000
# tax is: 120000.0

# %% [markdown]
# # 16.Finding the Middle Number

# %%
num1=int(input("enter the 1st num:"))
num2=int(input("enter the 2nd num:"))
num3=int(input("enter the 3rd num:"))
if num1>=num2 and num1>=num3:
    if num2>=num3:
        print("Middle no is:",num2)
    else:
        print("Middle no is:",num3)
elif num2>=num1 and num2>=num3:
    if num1>=num3:
        print("Middle no is:",num1)
    else:
        print("Middle no is:",num3)
else:
    if num1>=num2:
        print("Middle no is:",num1)
    else:
        print("Middle no is:",num2)
# Out:
# enter the 1st num: 23
# enter the 2nd num: 45
# enter the 3rd num: 2
# Middle no is: 23

# %% [markdown]
# # 17.Find the greatest number

# %%
num1=int(input("enter the 1st num:"))
num2=int(input("enter the 2nd num:"))
num3=int(input("enter the 3rd num:"))
if num1>=num2 and num1>=num3:
   print("greatest no is:",num1)
elif num2>=num1 and num2>=num3:
    print("greatest no is:",num2)
else:
    print("greatest no is:",num3)
# Out:
# enter the 1st num: 23
# enter the 2nd num: 1
# enter the 3rd num: 45
# greatest no is: 45

# %% [markdown]
# # 18.Authentication System

# %%
Username= "user1" 
password="pass@123"
use_name=input("enter the user name:")
pass_word=input("enter the password:")
if use_name==Username and pass_word==password:
    print("Authentication successful.")
else:
    print( "Authentication failed.")
# Out:
# enter the user name: user2
# enter the password: kndvue
# Authentication failed.

# %% [markdown]
# # 19.Calculate Class Attendance Percentage

# %%
per=float(input("enter your attendance percentage:"))
if per>=75:
    print(f"Eligible to sit in the exam and your Attendance percentage is {per}")
else:
    print(f" not eligible to sit in the exam and beacuse your Attendance percentage is {per}")
# Out:
# enter your attendance percentage: 67.88
#  not eligible to sit in the exam and beacuse your Attendance percentage is 67.88

# %% [markdown]
# # 20.Library Charge Calculation

# %%
day=int(input("the number of days a book has been borrowed.:"))
if day>=0 and day<=5:
    charge=day*2
    print("total charges is:",charge)
elif day>=6 and day<=510:
    charge=day*3
    print("total charges is:",charge)
elif day>=11 and day<=15:
    charge=day*4
    print("total charges is:",charge)
elif day>=16:
    charge=day*5
    print("total charges is:",charge)
else:
    print("invlaid input plz enter the vlaid input")
# Out:
# the number of days a book has been borrowed.: 5
# total charges is: 10

# %% [markdown]
# # 21.UPSC Selection Process

# %%
pre_cutoff=500
main_cutoff=600
int_viewcutoff=700
age=int(input("enter your age:"))
if age>=21 and age<=32:
    gra=input("enter your graduation status 'yes' or 'no':")
    if gra=="yes":
        nati=input("enter the nationality")
        if nati=="indian":
            pre_score=float(input("enter your prelims score:"))
            if pre_score>=pre_cutoff:
                main_score=float(input("enter you main score:"))
                if main_score>=main_cutoff:
                    int_view=float(input("enter your interview score:"))
                    if int_view>=int_viewcutoff:
                        print("Congratulations! You have cleared the UPSC.")
                    else:
                        print("You failed the Interview")
                else:
                    print("You failed the mains")
            else:
                print("You failed the Prelims.")
        else:
            print("ineligible beacuse you are not indian")
    else:
        print("ineligible beacuse you are not graduate")
else:
    print(" ineligible beacuse you are not in the range of age")
# Out:
# enter your age: 20
#  ineligible beacuse you are not in the range of age

# %% [markdown]
# # 22. Menu-Driven Login System

# %%
Phone_number= "1234567890"
OTP="1234"
Email="user@example.com"
Password="password123"
a=input("""
    Enter 1 if you want login with Phone.
    Enter 2 if you want login with Email.
    Enter 3 if you want Exit the system.
""")
if a=="1":
    phone=input("enter the phone number:")
    otp=input("enter the otp which is sended on your regi. phone:")
    if phone==Phone_number and otp==OTP:
        print("login successfully with phone")
    else:
        print("invalid phone or otp")
elif a=="2":
    email=input("enter your email:")
    password=input("enter your password:")
    if email==Email and password==Password:
        print("Login successful with email!")
    else:
        print("invlaid email or password:!")
elif a=="3":
    print( "Exiting the program. Have a nice day!")
else:
    print("plz enter the vlaid input")
# Out:
#     Enter 1 if you want login with Phone.
#     Enter 2 if you want login with Email.
#     Enter 3 if you want Exit the system.
#  1
# enter the phone number: 1234567890
# enter the otp which is sended on your regi. phone: 1234
# login successfully with phone

# %% [markdown]
# # 23 .Create Your Own KBC Game

# %%
total_score=0
q1=input("""
    Q1  Who was the first child born to English parents in North America in 1587?
        A. Virginia Dare, B. John White, C. Elizabeth Raleigh, D. William Dare
""")
ans=input("chose your correct option given below!").upper()
if ans=="A":
    total_score+=1000
    
else:
    print("wrong answer! thank you for the participating")
